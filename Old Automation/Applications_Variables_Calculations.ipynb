# %%
#BABUSC DOMESTIC Year 1----------------------------------------------------------------------------------------------------

#BABUSC DOMESTIC Year 1 Total Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1 = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1'))
]

term_1_BABUSC_DOMESTIC_Year_1_Applications = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Accepted Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Accepted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Accepted'].isin(['ACPT', 'ACLN', 'COND'])) &
    ~(df_term_1_details['Deferred Application'].isin(['ACPT', 'COND']))
]

term_1_BABUSC_DOMESTIC_Year_1_Accepted = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Accepted)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Accepted) > 0
    else None
)
#BABUSC DOMESTIC Year 1 Payment Pending Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Payment_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    ~((df_term_1_details['Payment Pending'].isna()) | (df_term_1_details['Payment Pending'] == ''))
]

term_1_BABUSC_DOMESTIC_Year_1_Payment_Pending = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Payment_Pending)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Payment_Pending) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Denied Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Denied = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Denied'].isin(['APEX', 'DENY', 'NTSL']))
]

term_1_BABUSC_DOMESTIC_Year_1_Denied = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Denied)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Denied) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Declined Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Declined = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Declined'].isin(['CCAN', 'DECL']))
]

term_1_BABUSC_DOMESTIC_Year_1_Declined = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Declined)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Declined) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Pending Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Pending'].isin(['APRO', 'NODE']))
]

term_1_BABUSC_DOMESTIC_Year_1_Pending = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Pending)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Pending) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Waitlisted Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Waitlisted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Waitlisted'].isin(['CDMT', 'RQMT', 'WAIT']))
]

term_1_BABUSC_DOMESTIC_Year_1_Waitlisted = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Waitlisted)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Waitlisted) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Enrolled Applications
df_term_1_details_BABUSC_DOMESTIC_Year_1_Enrolled = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Enrollment'].isin(['ENRO']))
]

term_1_BABUSC_DOMESTIC_Year_1_Enrolled = (
    len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Enrolled)
    if len(df_term_1_details_BABUSC_DOMESTIC_Year_1_Enrolled) > 0
    else None
)

#BABUSC DOMESTIC Year 1 Conversion Rate
term_1_BABUSC_DOMESTIC_Year_1_Conversion_Rate = division_calculator_decimal(term_1_BABUSC_DOMESTIC_Year_1_Enrolled, term_1_BABUSC_DOMESTIC_Year_1_Accepted)

#BABUSC INTERNATIONAL Year 1----------------------------------------------------------------------------------------------------

#BABUSC INTERNATIONAL Year 1 Total Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1 = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1'))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Applications = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Accepted Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Accepted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Accepted'].isin(['ACPT', 'ACLN', 'COND'])) &
    ~(df_term_1_details['Deferred Application'].isin(['ACPT', 'COND']))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Accepted = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Accepted)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Accepted) > 0
    else None
)
#BABUSC INTERNATIONAL Year 1 Payment Pending Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Payment_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    ~((df_term_1_details['Payment Pending'].isna()) | (df_term_1_details['Payment Pending'] == ''))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Payment_Pending = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Payment_Pending)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Payment_Pending) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Denied Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Denied = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Denied'].isin(['APEX', 'DENY', 'NTSL']))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Denied = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Denied)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Denied) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Declined Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Declined = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Declined'].isin(['CCAN', 'DECL']))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Declined = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Declined)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Declined) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Pending Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Pending'].isin(['APRO', 'NODE']))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Pending = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Pending)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Pending) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Waitlisted Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Waitlisted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Waitlisted'].isin(['CDMT', 'RQMT', 'WAIT']))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Waitlisted = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Waitlisted)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Waitlisted) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Enrolled Applications
df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Enrolled = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BABUSC'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Enrollment'].isin(['ENRO']))
]

term_1_BABUSC_INTERNATIONAL_Year_1_Enrolled = (
    len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Enrolled)
    if len(df_term_1_details_BABUSC_INTERNATIONAL_Year_1_Enrolled) > 0
    else None
)

#BABUSC INTERNATIONAL Year 1 Conversion Rate
term_1_BABUSC_INTERNATIONAL_Year_1_Conversion_Rate = division_calculator_decimal(term_1_BABUSC_INTERNATIONAL_Year_1_Enrolled, term_1_BABUSC_INTERNATIONAL_Year_1_Accepted)

#BAACTD DOMESTIC Year 1----------------------------------------------------------------------------------------------------

#BAACTD DOMESTIC Year 1 Total Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1 = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1'))
]

term_1_BAACTD_DOMESTIC_Year_1_Applications = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Accepted Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Accepted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Accepted'].isin(['ACPT', 'ACLN', 'COND'])) &
    ~(df_term_1_details['Deferred Application'].isin(['ACPT', 'COND']))
]

term_1_BAACTD_DOMESTIC_Year_1_Accepted = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Accepted)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Accepted) > 0
    else None
)
#BAACTD DOMESTIC Year 1 Payment Pending Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Payment_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    ~((df_term_1_details['Payment Pending'].isna()) | (df_term_1_details['Payment Pending'] == ''))
]

term_1_BAACTD_DOMESTIC_Year_1_Payment_Pending = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Payment_Pending)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Payment_Pending) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Denied Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Denied = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Denied'].isin(['APEX', 'DENY', 'NTSL']))
]

term_1_BAACTD_DOMESTIC_Year_1_Denied = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Denied)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Denied) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Declined Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Declined = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Declined'].isin(['CCAN', 'DECL']))
]

term_1_BAACTD_DOMESTIC_Year_1_Declined = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Declined)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Declined) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Pending Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Pending'].isin(['APRO', 'NODE']))
]

term_1_BAACTD_DOMESTIC_Year_1_Pending = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Pending)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Pending) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Waitlisted Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Waitlisted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Waitlisted'].isin(['CDMT', 'RQMT', 'WAIT']))
]

term_1_BAACTD_DOMESTIC_Year_1_Waitlisted = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Waitlisted)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Waitlisted) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Enrolled Applications
df_term_1_details_BAACTD_DOMESTIC_Year_1_Enrolled = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['DOMESTIC'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Enrollment'].isin(['ENRO']))
]

term_1_BAACTD_DOMESTIC_Year_1_Enrolled = (
    len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Enrolled)
    if len(df_term_1_details_BAACTD_DOMESTIC_Year_1_Enrolled) > 0
    else None
)

#BAACTD DOMESTIC Year 1 Conversion Rate
term_1_BAACTD_DOMESTIC_Year_1_Conversion_Rate = division_calculator_decimal(term_1_BAACTD_DOMESTIC_Year_1_Enrolled, term_1_BAACTD_DOMESTIC_Year_1_Accepted)

#BAACTD INTERNATIONAL Year 1----------------------------------------------------------------------------------------------------

#BAACTD INTERNATIONAL Year 1 Total Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1 = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1'))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Applications = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Accepted Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Accepted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Accepted'].isin(['ACPT', 'ACLN', 'COND'])) &
    ~(df_term_1_details['Deferred Application'].isin(['ACPT', 'COND']))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Accepted = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Accepted)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Accepted) > 0
    else None
)
#BAACTD INTERNATIONAL Year 1 Payment Pending Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Payment_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    ~((df_term_1_details['Payment Pending'].isna()) | (df_term_1_details['Payment Pending'] == ''))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Payment_Pending = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Payment_Pending)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Payment_Pending) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Denied Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Denied = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Denied'].isin(['APEX', 'DENY', 'NTSL']))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Denied = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Denied)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Denied) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Declined Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Declined = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Declined'].isin(['CCAN', 'DECL']))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Declined = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Declined)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Declined) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Pending Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Pending = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Pending'].isin(['APRO', 'NODE']))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Pending = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Pending)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Pending) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Waitlisted Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Waitlisted = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Waitlisted'].isin(['CDMT', 'RQMT', 'WAIT']))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Waitlisted = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Waitlisted)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Waitlisted) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Enrolled Applications
df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Enrolled = df_term_1_details[
    (df_term_1_details['CURRICULUM'].str.replace(' ','').str.upper().isin(['BAACTD'])) &
    (df_term_1_details['Population'].str.replace(' ','').str.upper().isin(['INTERNATIONAL'])) &
    (df_term_1_details['Year'].astype(str).str.strip() == str('1')) &
    (df_term_1_details['Enrollment'].isin(['ENRO']))
]

term_1_BAACTD_INTERNATIONAL_Year_1_Enrolled = (
    len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Enrolled)
    if len(df_term_1_details_BAACTD_INTERNATIONAL_Year_1_Enrolled) > 0
    else None
)

#BAACTD INTERNATIONAL Year 1 Conversion Rate
term_1_BAACTD_INTERNATIONAL_Year_1_Conversion_Rate = division_calculator_decimal(term_1_BAACTD_INTERNATIONAL_Year_1_Enrolled, term_1_BAACTD_INTERNATIONAL_Year_1_Accepted)
